# %%
# %pip install hl7
# Out:
# Requirement already satisfied: hl7 in c:\users\emma1\anaconda3\lib\site-packages (0.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install hl7apy
# Out:
# Collecting hl7apy
#   Obtaining dependency information for hl7apy from https://files.pythonhosted.org/packages/91/f7/1150f6d878a05272858a9a2dedd5466e06003a02dd7c555b51f299656178/hl7apy-1.3.5-py2.py3-none-any.whl.metadata
#   Downloading hl7apy-1.3.5-py2.py3-none-any.whl.metadata (2.0 kB)
# Downloading hl7apy-1.3.5-py2.py3-none-any.whl (974 kB)
#    ---------------------------------------- 0.0/974.7 kB ? eta -:--:--
#    - ------------------------------------- 30.7/974.7 kB 640.0 kB/s eta 0:00:02
#    ----- ---------------------------------- 143.4/974.7 kB 1.7 MB/s eta 0:00:01
#    ------------------------------- -------- 757.8/974.7 kB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 974.7/974.7 kB 6.8 MB/s eta 0:00:00
# Installing collected packages: hl7apy
# Successfully installed hl7apy-1.3.5
# Note: you may need to restart the kernel to use updated packages.

# %%
txt_file_path='assets/dataToUpload/paciente3.txt'
with open(txt_file_path, 'r') as txt_file:
# Leer el contenido del archivo línea por línea
  lista = txt_file.readlines()

# %%
for i in lista:
  print(i)
# Out:
# 1H|\^&|||D10^01^3.00|||||||||20240129133654
#
# 07
#
# 2P|1
#
# 3F
#
# 3O|1|1234567890|1311159-02-015-20240119-01|^^^43||||||||Juan AndrÃ©s|SepÃºlveda Ramos||||||||||||||M
#
# EA
#
# 4R|1|^^^A1b^AREA|3.7|||||||||20240129133654
#
# 62
#
# 5R|2|^^^A1b^TIME|0.25|||||||||20240129133654
#
# A7
#
# 6R|3|^^^F^AREA|9.8|||||||||20240129133654
#
# DF
#
# 7R|4|^^^F^TIME|0.56|||||||||20240129133654
#
# 21
#
# 0R|5|^^^A1c^AREA|5.9|||||||||20240129133654
#
# 67
#
# 1R|6|^^^A1c^TIME|0.88|||||||||20240129133654
#
# B1
#
# 2R|7|^^^P3^AREA|4.1|||||||||20240129133654
#
# 10
#
# 3R|8|^^^P3^TIME|1.37|||||||||20240129133654
#
# 5E
#
# 4R|9|^^^A0^AREA|53.6|||||||||20240129133654
#
# 3B
#
# 5R|10|^^^A0^TIME|1.45|||||||||20240129133654
#
# 76
#
# 6R|11|^^^S-Window^AREA|26.2|||||||||20240129133654
#
# E9
#
# 7R|12|^^^S-Window^TIME|1.65|||||||||20240129133654
#
# 03
#
# 0R|13|^^^TOTAL^AREA|2587336|||||||||20240129133654
#
# 1B
#
# 1L|1|N
#
# 04

# %%
dic={}
fecha=lista[0].split("|")[-1].split("\n")[0]
cedula=lista[4].split('|')[2]
edad=lista[4].split('|')[4].split('^')[3]
nombre=lista[4].split('|')[12]
apellidos=lista[4].split('|')[13]
sexo=lista[4].split('|')[27].split('\n')[0]


dic['Fecha']=fecha
dic['Cedula']=cedula
dic['Edad']=edad
dic['Nombre']=nombre
dic['Apellidos']=apellidos
dic['Sexo']=sexo

examenes = []
for position, i in enumerate(lista[10:28:2]):
  nombre_examen=i.split("|")[2].split("^")[3]
  resultado=i.split("|")[3]

  examen={
      "examen": nombre_examen,
      "resultado": resultado
  }
  if (position == 0 or position == 2 or position == 8):
    examenes.append(examen)
print(examenes)

dic['Examenes']=examenes
# Out:
# [{'examen': 'F', 'resultado': '9.8'}, {'examen': 'A1c', 'resultado': '5.9'}, {'examen': 'S-Window', 'resultado': '26.2'}]

# %%
dic
# Out:
# {'Fecha': '20240129133654',
#  'Cedula': '1234567890',
#  'Edad': '43',
#  'Nombre': 'Juan AndrÃ©s',
#  'Apellidos': 'SepÃºlveda Ramos',
#  'Sexo': 'M',
#  'Examenes': [{'examen': 'F', 'resultado': '9.8'},
#   {'examen': 'A1c', 'resultado': '5.9'},
#   {'examen': 'S-Window', 'resultado': '26.2'}]}
